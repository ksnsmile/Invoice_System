# %% [markdown]
# # 송장 감지

# %%
import os

# Git 실행 파일 경로 설정
os.environ['GIT_PYTHON_GIT_EXECUTABLE'] = r'C:\Program Files\Git\bin\bin\git.exe'  # Git 설치 경로 확인 후 수정

# Git 오류 무시 옵션 설정
os.environ['GIT_PYTHON_REFRESH'] = 'quiet'

# %%
# !git --version
# Out:
# git version 2.40.1.windows.1

# %%
# !python train.py --data "data\custom_dataset.yaml" --weights "yolov5x6.pt" --img 1536 --epochs 600 --patience 0
# Out:
# train: weights=yolov5x6.pt, cfg=, data=data\custom_dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=600, batch_size=16, imgsz=1536, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=0, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# From https://github.com/ultralytics/yolov5
#    ab364c98..ff063284  master     -> origin/master
# github:  YOLOv5 is out of date by 55 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# ...

# %%
# !python val.py --data "data/custom_dataset.yaml" --weights "runs/train/exp9/weights/best.pt"

# %%
# best 결과 사용
# 마지막 Results saved to runs\detect\exp34 폴더에 저장된 결과 확인
# !python detect.py --img 1536 --weights "runs/train/exp19/weights/best.pt" --source "custom_dataset/test/images" --conf-thres 0.9 --save-crop
# Out:
# detect: weights=['runs/train/exp19/weights/best.pt'], source=custom_dataset/test/images, data=data\coco128.yaml, imgsz=[1536, 1536], conf_thres=0.9, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-283-g875d9278 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
#
# Fusing layers...
# Model summary: 416 layers, 139970872 parameters, 0 gradients, 207.9 GFLOPs
# image 1/3574 C:\Users\USER\Desktop\sunny\yolov5\custom_dataset\test\images\CAM 20231028070900_1.bmp: 1344x1536 1 invoice, 97.3ms
# image 2/3574 C:\Users\USER\Desktop\sunny\yolov5\custom_dataset\test\images\CAM 20231028070900_2.bmp: 1344x1536 (no detections), 48.4ms
# ...

# %%
# 이 후 Desktop/sunny/yolov5/runs/detect/exp00 에서 결과 확인

# %%
# best 결과 사용
# 마지막 Results saved to runs\detect\exp34 폴더에 저장된 결과 확인
# !python detect.py --img 1536 --weights "runs/train/exp19/weights/best.pt" --source "D:/추가 송장" --conf-thres 0.9 --save-crop --project "D:/"
# Out:
# detect: weights=['runs/train/exp19/weights/best.pt'], source=D:/ , data=data\coco128.yaml, imgsz=[1536, 1536], conf_thres=0.9, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=D:/, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-283-g875d9278 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
#
# Fusing layers...
# Model summary: 416 layers, 139970872 parameters, 0 gradients, 207.9 GFLOPs
# image 1/99 D:\ \KakaoTalk_20240320_171248347_01.jpg: 1536x1152 1 invoice, 98.1ms
# image 2/99 D:\ \KakaoTalk_20240320_171248347_02.jpg: 1536x1152 1 invoice, 48.2ms
# image 3/99 D:\ \KakaoTalk_20240320_171248347_03.jpg: 1152x1536 1 invoice, 100.0ms
# image 4/99 D:\ \KakaoTalk_20240320_171248347_04.jpg: 1152x1536 1 invoice, 40.6ms
# ...
